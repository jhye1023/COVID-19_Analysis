# %%
import pandas as pd
data = pd.read_json(path_or_buf ='https://api.covidtracking.com/v1/us/daily.json')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   date                      317 non-null    int64
#  1   states                    317 non-null    int64
#  2   positive                  317 non-null    int64
#  3   negative                  317 non-null    int64
#  4   pending                   275 non-null    float64
#  5   hospitalizedCurrently     262 non-null    float64
#  6   hospitalizedCumulative    275 non-null    float64
#  7   inIcuCurrently            253 non-null    float64
#  8   inIcuCumulative           254 non-null    float64
#  9   onVentilatorCurrently     254 non-null    float64
#  10  onVentilatorCumulative    247 non-null    float64
#  11  recovered                 254 non-null    float64
#  12  dateChecked               317 non-null    object
# ...

# %%
data.head()
# Out:
#        date  states  positive   negative  pending  hospitalizedCurrently  \
# 0  20201203      56  13921312  157030850  15106.0               100667.0
# 1  20201202      56  13711151  155812953  14368.0               100226.0
# 2  20201201      56  13515456  154845511   8764.0                98691.0
# 3  20201130      56  13338671  153864364  14883.0                96053.0
# 4  20201129      56  13191088  152644567  14860.0                93265.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                575452.0         19442.0          31276.0
# 1                570121.0         19396.0          31038.0
# 2                565093.0         19035.0          30749.0
# 3                559871.0         18545.0          30469.0
# 4                556477.0         18201.0          30274.0
#
#    onVentilatorCurrently  ...  totalTestResults          lastModified total  \
# 0                 6867.0  ...         197409766  2020-12-03T24:00:00Z     0
# ...

# %%
data.plot()

# %%
data.columns
# Out:
# Index(['date', 'states', 'positive', 'negative', 'pending',
#        'hospitalizedCurrently', 'hospitalizedCumulative', 'inIcuCurrently',
#        'inIcuCumulative', 'onVentilatorCurrently', 'onVentilatorCumulative',
#        'recovered', 'dateChecked', 'death', 'hospitalized', 'totalTestResults',
#        'lastModified', 'total', 'posNeg', 'deathIncrease',
#        'hospitalizedIncrease', 'negativeIncrease', 'positiveIncrease',
#        'totalTestResultsIncrease', 'hash'],
#       dtype='object')

# %%
increase_data = data.loc[:,['date','deathIncrease','hospitalizedIncrease', 'negativeIncrease', 'positiveIncrease']]
increase_data.head()
# Out:
#        date  deathIncrease  hospitalizedIncrease  negativeIncrease  \
# 0  20201203           2706                  5331           1217897
# 1  20201202           2733                  5028            967442
# 2  20201201           2473                  5222            981147
# 3  20201130           1136                  3394           1219797
# 4  20201129            803                  2429            883117
#
#    positiveIncrease
# 0            210161
# 1            195695
# 2            176785
# 3            147583
# 4            135242

# %%
final_data = increase_data.astype({'date':'str'})
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317 entries, 0 to 316
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   date                  317 non-null    object
#  1   deathIncrease         317 non-null    int64
#  2   hospitalizedIncrease  317 non-null    int64
#  3   negativeIncrease      317 non-null    int64
#  4   positiveIncrease      317 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 12.5+ KB

# %%
final_data.set_index('date', inplace=True)
final_data.head()
# Out:
#           deathIncrease  hospitalizedIncrease  negativeIncrease  \
# date
# 20201203           2706                  5331           1217897
# 20201202           2733                  5028            967442
# 20201201           2473                  5222            981147
# 20201130           1136                  3394           1219797
# 20201129            803                  2429            883117
#
#           positiveIncrease
# date
# 20201203            210161
# 20201202            195695
# 20201201            176785
# 20201130            147583
# 20201129            135242

# %%
final_data.plot()

# %%
final_data.sort_values(by='date', inplace=True)
final_data.plot()

# %%
final_data.plot(subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f9bb9a9d090>,
# ...
#       dtype=object)

# %%
final_data[-15:].plot()

# %%
final_data[-15:].plot.bar(stacked=True)

# %%
final_data.plot.bar(stacked=True)

# %%
final_data.plot(subplots=True, layout=(2,2))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f9bba00afd0>,
# ...
#       dtype=object)
